# %% [markdown]
# <a href="https://colab.research.google.com/github/HusseK/ResacNet/blob/main/5100it%C3%A9rations.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
from tensorflow import keras
from keras.models import load_model

model= load_model('/content/drive/MyDrive/TRIED/Projet Long/test_save_husseine')

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_1 (InputLayer)            [(None, 16, 17, 1)]  0
# __________________________________________________________________________________________________
# up_sampling2d (UpSampling2D)    (None, 48, 51, 1)    0           input_1[0][0]
# __________________________________________________________________________________________________
# input_2 (InputLayer)            [(None, 48, 51, 1)]  0
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 48, 51, 2)    0           up_sampling2d[0][0]
#                                                                  input_2[0][0]
# __________________________________________________________________________________________________
# ...

# %%
model.load_weights('/content/drive/MyDrive/TRIED/Projet Long/SaveModel/modelkvalid.ckpt')
model

# %%
import pickle
with open('/content/drive/MyDrive/TRIED/Projet Long/SaveModel/modelkhistory.pkl', 'rb') as file:
        H=pickle.load(file)

len(H.keys())
# Out:
# 10

# %%
import matplotlib.pyplot as plt
import random

number_of_colors = len(H.keys())

color = ["#"+''.join([random.choice('0123456789ABCDEF') for j in range(6)])
             for i in range(number_of_colors)]
print(color)
# Out:
# ['#54EDF1', '#D3500C', '#60FBA7', '#14E9DB', '#A557BB', '#9DB731', '#6225DE', '#D64EDC', '#71E636', '#806422']

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

H.keys()
plt.figure(figsize=(26,26))
LH = []
kh = H.keys()
LH.append(kh);            
for i,kle in enumerate(H.keys()) :
  hloss = H[kle]
  plt.plot(np.log(hloss), alpha=0.5)
  hloss = np.reshape(hloss,(1,len(hloss)))
  LH.append(hloss[0])               
plt.legend(H.keys(), framealpha=0.3, loc=0)
plt.xlabel('epoch')    
plt.ylabel('log(loss)')
#plt.savefig("/content/drive/MyDrive/TRIED/Projet Long/loss.png")#,dpi=900)
# Out:
# Text(0, 0.5, 'log(loss)')
